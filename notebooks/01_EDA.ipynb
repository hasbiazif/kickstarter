# %% [markdown]
# # import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
# atur style visualisasi
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (8, 4)

# %%
df = pd.read_csv('C:\Mini_H\kickstarter\data\kickstarter.csv')
print("Data Shape ;", df.shape)
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\Mugis\AppData\Local\Temp\ipykernel_10984\3561966637.py:1: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv('C:\Mini_H\kickstarter\data\kickstarter.csv')
# Data Shape ; (257692, 42)
#    backers_count                                              blurb  \
# 0             42  Students from 3 universities are designing a d...
# 1             72  Mission to launch a vintage Action Man and Spa...
# 2            908  The first space program for satellite developm...
# 3             39  Eeveelutions & Pokemon Japanese Wagashi Mochi ...
# 4             67  Large and detailed Sailor Moon inspired romant...
#
#                                             category  \
# 0  {"id":340,"name":"Space Exploration","analytic...
# 1  {"id":340,"name":"Space Exploration","analytic...
# 2  {"id":340,"name":"Space Exploration","analytic...
# 3  {"id":289,"name":"Textiles","analytics_name":"...
# 4  {"id":289,"name":"Textiles","analytics_name":"...
#
#    converted_pledged_amount country country_displayable_name  created_at  \
# 0                    1466.0      US        the United States  1459792338
# 1                    4963.0      GB       the United Kingdom  1454944458
# 2                   81369.0      US        the United States  1453930744
# 3                    1466.0      US        the United States  1551909261
# 4                    2894.0      US        the United States  1549585291
#
#                                              creator currency currency_symbol  \
# 0  {"id":745377438,"name":"Sebastian Brownstein",...      USD               $
# 1  {"id":902832810,"name":"Rob Wisdom","slug":"ac...      GBP               £
# 2  {"id":715563550,"name":"ACAE","slug":"irazu","...      USD               $
# 3  {"id":1776595608,"name":"Studio Min Bin Bin","...      USD               $
# 4  {"id":1776595608,"name":"Studio Min Bin Bin","...      USD               $
#
#    ...  spotlight staff_pick       state  state_changed_at  static_usd_rate  \
# 0  ...       True      False  successful        1464485340         1.000000
# 1  ...       True      False  successful        1462017600         1.420606
# 2  ...       True      False  successful        1461155656         1.000000
# 3  ...       True      False  successful        1554080403         1.000000
# 4  ...       True      False  successful        1552183200         1.000000
#
#                                                 urls  usd_exchange_rate  \
# 0  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 1  {"web":{"project":"https://www.kickstarter.com...           1.461095
# 2  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 3  {"web":{"project":"https://www.kickstarter.com...           1.000000
# 4  {"web":{"project":"https://www.kickstarter.com...           1.000000
#
#     usd_pledged  usd_type                                              video
# 0   1466.000000  domestic  {"id":663518,"status":"successful","hls":null,...
# 1   4825.798208  domestic  {"id":649273,"status":"successful","hls":null,...
# 2  81369.000000  domestic  {"id":646478,"status":"successful","hls":null,...
# 3   1466.000000  domestic                                                NaN
# 4   2894.000000  domestic                                                NaN
#
# [5 rows x 42 columns]

# %%
# info dataset
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257692 entries, 0 to 257691
# Data columns (total 42 columns):
#  #   Column                              Non-Null Count   Dtype
# ---  ------                              --------------   -----
#  0   backers_count                       257692 non-null  int64
#  1   blurb                               257632 non-null  object
#  2   category                            257692 non-null  object
#  3   converted_pledged_amount            239943 non-null  float64
#  4   country                             257692 non-null  object
#  5   country_displayable_name            257692 non-null  object
#  6   created_at                          257692 non-null  int64
#  7   creator                             257692 non-null  object
#  8   currency                            257692 non-null  object
#  9   currency_symbol                     257692 non-null  object
#  10  currency_trailing_code              257692 non-null  bool
#  11  current_currency                    257692 non-null  object
#  12  deadline                            257692 non-null  int64
#  13  disable_communication               257692 non-null  bool
#  14  fx_rate                             257692 non-null  float64
#  15  goal                                257692 non-null  float64
#  16  id                                  257692 non-null  int64
#  17  is_disliked                         257692 non-null  bool
#  18  is_in_post_campaign_pledging_phase  89400 non-null   object
#  19  is_launched                         257692 non-null  bool
#  20  is_liked                            257692 non-null  bool
#  21  is_starrable                        257692 non-null  bool
#  22  launched_at                         257692 non-null  int64
#  23  location                            257338 non-null  object
#  24  name                                257692 non-null  object
#  25  percent_funded                      257692 non-null  float64
#  26  photo                               257692 non-null  object
#  27  pledged                             257692 non-null  float64
#  28  prelaunch_activated                 257692 non-null  bool
#  29  profile                             257692 non-null  object
#  30  slug                                257692 non-null  object
#  31  source_url                          257692 non-null  object
#  32  spotlight                           257692 non-null  bool
#  33  staff_pick                          257692 non-null  bool
#  34  state                               257692 non-null  object
#  35  state_changed_at                    257692 non-null  int64
#  36  static_usd_rate                     257692 non-null  float64
#  37  urls                                257692 non-null  object
#  38  usd_exchange_rate                   239943 non-null  float64
#  39  usd_pledged                         239943 non-null  float64
#  40  usd_type                            257680 non-null  object
#  41  video                               160158 non-null  object
# dtypes: bool(9), float64(8), int64(6), object(19)
# memory usage: 67.1+ MB
#        backers_count  converted_pledged_amount    created_at      deadline  \
# count  257692.000000              2.399430e+05  2.576920e+05  2.576920e+05
# mean      129.123853              1.754889e+04  1.588149e+09  1.486409e+09
# std       715.544073              2.124450e+05  1.305290e+08  4.081510e+08
# min         0.000000              0.000000e+00  1.240366e+09  0.000000e+00
# 25%         3.000000              2.250000e+02  1.469112e+09  1.447692e+09
# 50%        25.000000              2.079000e+03  1.610123e+09  1.577352e+09
# 75%        88.000000              8.154000e+03  1.715107e+09  1.715263e+09
# max    105857.000000              4.676226e+07  1.752472e+09  1.757657e+09
#
#              fx_rate          goal            id   launched_at  \
# count  257692.000000  2.576920e+05  2.576920e+05  2.576920e+05
# mean        0.983447  5.416623e+04  1.075759e+09  1.475042e+09
# std         0.269565  2.981096e+06  6.192445e+08  4.205171e+08
# min         0.006789  0.000000e+00  1.358300e+04  0.000000e+00
# 25%         1.000000  1.000000e+03  5.406249e+08  1.442614e+09
# 50%         1.000000  4.500000e+03  1.075649e+09  1.571356e+09
# 75%         1.000000  1.200000e+04  1.611662e+09  1.711755e+09
# max         1.846127  1.000000e+09  2.147476e+09  1.752480e+09
#
#        percent_funded       pledged  state_changed_at  static_usd_rate  \
# count    2.576920e+05  2.576920e+05      2.576920e+05    257692.000000
# mean     7.154829e+02  4.801127e+04      1.595569e+09         0.912554
# std      5.536266e+04  9.096344e+05      1.305098e+08         0.356897
# min      0.000000e+00  0.000000e+00      1.242468e+09         0.000000
# 25%      1.677611e+00  1.000000e+02      1.476413e+09         1.000000
# 50%      1.024000e+02  1.740000e+03      1.618672e+09         1.000000
# 75%      1.418537e+02  8.160000e+03      1.723219e+09         1.000000
# max      1.553204e+07  2.193143e+08      1.752480e+09         1.716408
#
#        usd_exchange_rate   usd_pledged
# count      239943.000000  2.399430e+05
# mean            0.980030  1.754077e+04
# std             0.265672  2.123860e+05
# min             0.006186  0.000000e+00
# 25%             1.000000  2.250000e+02
# 50%             1.000000  2.077026e+03
# 75%             1.000000  8.157000e+03
# max             1.716408  4.676226e+07

# %%
missing = df.isnull().sum()
missing = missing[missing > 0].sort_values(ascending=False)
missing
# Out:
# is_in_post_campaign_pledging_phase    168292
# video                                  97534
# usd_exchange_rate                      17749
# converted_pledged_amount               17749
# usd_pledged                            17749
# location                                 354
# blurb                                     60
# usd_type                                  12
# dtype: int64

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=df, x='state', order=df['state'].value_counts().index)
plt.title('Distribusi Status Projek Kickstarter')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Karena kolom category tipe json maka kita rubah dahulu

# %%
# Fungsi untuk ekstrak nama kategori dari JSON
def extract_category_name(category_json):
    try:
        category_data = json.loads(category_json.replace("'", "\""))
        return category_data['name']
    except:
        return None

def extract_parent_category(category_json):
    try:
        category_data = json.loads(category_json.replace("'", "\""))
        return category_data['parent_name']
    except:
        return None

# Ekstrak informasi kategori
df['category_name'] = df['category'].apply(extract_category_name)
df['parent_category'] = df['category'].apply(extract_parent_category)

print("Sample data kategori:")
print(df[['category', 'category_name', 'parent_category']].head())
# Out:
# Sample data kategori:
#                                             category      category_name  \
# 0  {"id":340,"name":"Space Exploration","analytic...  Space Exploration
# 1  {"id":340,"name":"Space Exploration","analytic...  Space Exploration
# 2  {"id":340,"name":"Space Exploration","analytic...  Space Exploration
# 3  {"id":289,"name":"Textiles","analytics_name":"...           Textiles
# 4  {"id":289,"name":"Textiles","analytics_name":"...           Textiles
#
#   parent_category
# 0      Technology
# 1      Technology
# 2      Technology
# 3             Art
# 4             Art

# %%
# Hitung keberhasilan berdasarkan kategori utama (parent_category)
parent_success = df.groupby(['parent_category', 'state']).size().unstack(fill_value=0)
parent_success['success_rate'] = parent_success['successful'] / (parent_success['successful'] + parent_success['failed']) * 100

# Urutkan berdasarkan tingkat keberhasilan
parent_success = parent_success.sort_values('success_rate', ascending=False)
print("Tingkat Keberhasilan per Kategori Utama:")
print(parent_success[['success_rate']])
# Out:
# Tingkat Keberhasilan per Kategori Utama:
# state            success_rate
# parent_category
# Comics              87.698925
# Art                 73.854516
# Music               73.150885
# Theater             71.126314
# Games               69.695227
# Design              69.451800
# Film & Video        67.475251
# Publishing          65.354713
# Fashion             63.358427
# Photography         61.699755
# Technology          60.379277
# Dance               60.186092
# Crafts              44.086398
# Food                43.407720
# Journalism          36.222692

# %%
plt.figure(figsize=(10, 8))
bars = plt.barh(parent_success.index, parent_success['success_rate'], 
                color=plt.cm.viridis(parent_success['success_rate']/100))

plt.title('Tingkat Keberhasilan Projek per Kategori Utama', fontsize=16, fontweight='bold')
plt.xlabel('Tingkat Keberhasilan (%)', fontsize=12)
plt.ylabel('Kategori Utama', fontsize=12)
plt.grid(axis='x', alpha=0.3)

# Tambahkan nilai di ujung setiap bar
for bar in bars:
    width = bar.get_width()
    plt.text(width + 1, bar.get_y() + bar.get_height()/2,
             f'{width:.1f}%', ha='left', va='center', fontsize=9)

plt.tight_layout()
plt.show()

# %%
# Hitung untuk subkategori
category_success = df.groupby(['category_name', 'state']).size().unstack(fill_value=0)
category_success['success_rate'] = category_success['successful'] / (category_success['successful'] + category_success['failed']) * 100
category_success = category_success.sort_values('success_rate', ascending=False)
print("\nTop 10 Subkategori dengan Tingkat Keberhasilan Tertinggi:")
print(category_success[['success_rate']].head(10))
# Out:
# Top 10 Subkategori dengan Tingkat Keberhasilan Tertinggi:
# state           success_rate
# category_name
# Theater            99.513382
# Country & Folk     99.188641
# Indie Rock         98.957558
# Crafts             98.388829
# Photography        98.194946
# Hardware           98.187062
# Art Books          97.873211
# Rock               97.866667
# Narrative Film     97.747748
# Graphic Novels     97.316637

# %% [markdown]
# ## Distribusi Goal dan USD Pledged

# %%
# Filter data untuk visualisasi yang lebih baik
# Gunakan kolom 'goal' dan 'usd_pledged' yang tersedia
df_clean = df[(df['goal'] < df['goal'].quantile(0.95)) & 
              (df['usd_pledged'] < df['usd_pledged'].quantile(0.95))]

# Plot distribusi
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

sns.histplot(df_clean['goal'], bins=50, kde=True, ax=axes[0])
axes[0].set_title('Distribusi Goal Amount')
axes[0].set_xlabel('Goal Amount')

sns.histplot(df_clean['usd_pledged'], bins=50, kde=True, ax=axes[1])
axes[1].set_title('Distribusi USD Pledged Amount')
axes[1].set_xlabel('USD Pledged Amount')

plt.tight_layout()
plt.show()

# Statistik deskriptif
print("\nStatistik Goal Amount:")
print(df['goal'].describe())
print("\nStatistik USD Pledged Amount:")
print(df['usd_pledged'].describe())
# Out:
# Statistik Goal Amount:
# count    2.576920e+05
# mean     5.416623e+04
# std      2.981096e+06
# min      0.000000e+00
# 25%      1.000000e+03
# 50%      4.500000e+03
# 75%      1.200000e+04
# max      1.000000e+09
# Name: goal, dtype: float64
#
# Statistik USD Pledged Amount:
# count    2.399430e+05
# mean     1.754077e+04
# std      2.123860e+05
# min      0.000000e+00
# 25%      2.250000e+02
# 50%      2.077026e+03
# 75%      8.157000e+03
# max      4.676226e+07
# Name: usd_pledged, dtype: float64

# %%
# ubah kolom timestamp jadi datetime
df["launched_at"] = pd.to_datetime(df["launched_at"], unit="s")
df["deadline"] = pd.to_datetime(df["deadline"], unit="s")
df["created_at"] = pd.to_datetime(df["created_at"], unit="s")
df["state_changed_at"] = pd.to_datetime(df["state_changed_at"], unit="s")

df[["launched_at","deadline","created_at","state_changed_at"]].head()
# Out:
#           launched_at            deadline          created_at  \
# 0 2016-05-04 01:28:59 2016-05-29 01:28:59 2016-04-04 17:52:18
# 1 2016-03-24 11:56:04 2016-04-30 12:00:00 2016-02-08 15:14:18
# 2 2016-03-21 12:34:15 2016-04-20 12:34:15 2016-01-27 21:39:04
# 3 2019-03-11 05:10:11 2019-04-01 01:00:00 2019-03-06 21:54:21
# 4 2019-02-11 17:57:47 2019-03-10 02:00:00 2019-02-08 00:21:31
#
#      state_changed_at
# 0 2016-05-29 01:29:00
# 1 2016-04-30 12:00:00
# 2 2016-04-20 12:34:16
# 3 2019-04-01 01:00:03
# 4 2019-03-10 02:00:00

# %%
# hitung ulang durasi
df["duration_days"] = (df["deadline"] - df["launched_at"]).dt.days

# filter kampanye dengan durasi wajar (<= 100 hari)
df_duration = df[df["duration_days"].between(0, 100)]

plt.figure(figsize=(8,5))
sns.histplot(df_duration, x="duration_days", hue="state", multiple="stack", bins=30)
plt.title("Durasi Kampanye Kickstarter (0–100 hari)")
plt.xlabel("Durasi (hari)")
plt.show()

df_duration["duration_days"].describe()
# Out:
# count    256386.000000
# mean         31.115896
# std          14.854969
# min           0.000000
# 25%          27.000000
# 50%          30.000000
# 75%          35.000000
# max         100.000000
# Name: duration_days, dtype: float64

# %% [markdown]
# Kampanye normal biasanya 20–60 hari.
#
# Paling sering di kisaran 30 hari, sesuai rekomendasi Kickstarter.
#
# Kampanye terlalu lama (>70 hari) jarang sukses karena kehilangan momentum.
#
# Kalau dataset Anda punya kampanye ribuan hari → kemungkinan data error (timestamp tidak sinkron).

# %%
plt.figure(figsize=(8,5))
sns.histplot(df[df["backers_count"] < 2000], x="backers_count", hue="state", multiple="stack", bins=50)
plt.title("Distribusi Jumlah Backers (dibatasi <2000)")
plt.xlabel("Jumlah Backers")
plt.show()

df.groupby("state")["backers_count"].median().sort_values(ascending=False)
# Out:
# state
# successful    68.0
# live          13.0
# failed         3.0
# canceled       2.0
# started        0.0
# submitted      0.0
# suspended      0.0
# Name: backers_count, dtype: float64

# %% [markdown]
# Proyek sukses biasanya punya lebih banyak backers.
#
# Median backers proyek sukses jauh lebih tinggi daripada proyek gagal.

# %%
# Buat kolom goal dalam USD
df["usd_goal_real"] = df["goal"] * df["static_usd_rate"]

plt.figure(figsize=(8,6))
sns.scatterplot(
    data=df[(df["usd_goal_real"] > 0) & (df["usd_goal_real"] < 1e6) & (df["usd_pledged"] < 1e6)],
    x="usd_goal_real", y="usd_pledged", hue="state", alpha=0.4
)
plt.xscale("log")
plt.yscale("log")
plt.title("Target vs Pledged (log scale, <1M USD)")
plt.xlabel("Target (USD)")
plt.ylabel("Pledged (USD)")
plt.show()

# %%
success_rate_country = df.groupby("country")["state"].apply(lambda x: (x=="successful").mean()*100).sort_values(ascending=False)

plt.figure(figsize=(10,5))
success_rate_country.head(15).plot(kind="bar", color="purple")
plt.title("Top 15 Negara dengan Success Rate Tertinggi")
plt.ylabel("Success Rate (%)")
plt.show()
